# %% [markdown]
# <a href="https://colab.research.google.com/github/YARABATI-YASHWANTH/Playground/blob/master/Internal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # 1)write a Program for applying Decision Tree Classification model on any Dataset .

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
df = load_iris()
X = df['data']
y = df['target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
print(f"accuracy = {accuracy}")
cm = confusion_matrix(y_test,y_pred)
ConfusionMatrixDisplay(confusion_matrix=cm).plot()
# Out:
# accuracy = 0.9666666666666667

# %%
# 2) write a Program for applying Support Vector Machine model on any dataset

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
df = load_breast_cancer()
X = df['data']
y = df['target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
model = SVC(kernel='linear')
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
svm_cm = confusion_matrix(y_test,y_pred)
matrix = ConfusionMatrixDisplay(confusion_matrix=svm_cm)
matrix.plot()

# %%
# 3)write a Program for applying Navie Bayes model on any Dataset

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %%
df = load_breast_cancer()
X = df['data']
y = df['target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
bayes_cm = confusion_matrix(y_test,y_pred)
matrix = ConfusionMatrixDisplay(confusion_matrix=bayes_cm)
matrix.plot()

# %%
# 4) write a Program for applying Linear Regression model on any Dataset

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
df = load_diabetes()
X,y = df['data'],df['target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test,y_pred)
print(f"mean_squared_error : {mse}")
mae = mean_absolute_error(y_test,y_pred)
print(f"mean_absolute_error : {mae}")
r2 = r2_score(y_test,y_pred)
print(f"r2_score : {r2}")
# Out:
# mean_squared_error : 3330.040934509684
# mean_absolute_error : 47.33195322734043
# r2_score : 0.4567092853959498

# %%
# 5)Visualize the Decision Tree.

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plot_tree(model,feature_names=iris['feature_names'],class_names=iris['target_names'],filled=True)
plt.show()

# %% [markdown]
# # 6) Visualize the Cluster Using Simple K-Means.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X,_ = make_blobs(n_samples=100,centers=3,random_state=42)
model = KMeans(n_clusters=3)
model.fit(X)
clusters = model.predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=clusters)

# %%
centroids = model.cluster_centers_
centroids
# Out:
# array([[-6.95170962, -6.67621669],
#        [ 4.49951001,  1.93892013],
#        [-2.66780392,  8.93576069]])

# %%
plt.scatter(X[:,0],X[:,1],c=clusters)
plt.scatter(centroids[:,0],centroids[:,1],color='red',s=100)
